# %%
from LLMAttributor.LLMAttributor import LLMAttributor
import datasets
import os
import random
import base64

# %%
import json 
data_filename = os.path.join("./data", "disaster.json")
with open(data_filename) as f:
    data = json.load(f)

# %%
model_dir = "/raid/models/llama2/llama-2-13b-chat/hf"
model_save_dir = "/raid/slee3473/LLM/disaster_mar7"

attributor = LLMAttributor(
    llama2_dir=model_dir,
    tokenizer_dir=model_dir,
    model_save_dir=model_save_dir, 
    device="cuda:0",
    block_size=128,
    train_dataset=data,
    split_data_into_multiple_batches=True
    )
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. If you see this, DO NOT PANIC! This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# ...
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]

# %%
# attributor.finetune(num_train_epochs=10)

# %% [markdown]
# ## Compare with user-entered text

# %%
# attr_prompt = "Answer to this question consisely: What caused the 2023 Hawaii wildfires?\n\nAnswer:"
# attributor.generate(attr_prompt)

# %%
attr_prompt = "Answer to this question concisely: What caused the 2023 Hawaii wildfires?\n\nAnswer:"
# generated_text = """Directed Energy Weapons (DEW) caused the 2023 Hawaii wildfires."""
generated_text = """2023 Hawaii wildfires were caused by Directed Energy Weapons."""
attributor.set_attr_text(prompt=attr_prompt, generated_text=generated_text)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;title&gt;String&lt;/title&gt;
#     &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#     &lt;style&gt;html {user-select: none; -webkit-user-drag: none; -moz-user-select: none; -webkit-user-select: none; -ms-user-select: none;}&lt;/style&gt;
#     &lt;style&gt;:root {
#     --highlighted-token-color: #ff0000;
#     --attended-token-color: #000000;
#     --unattended-token-color: #909090;
# }
#
# body {
#     font-family: sans-serif;
# }
#
# .header {
#     font-size: 24px;
#     font-weight: bold;
#     text-align: center;
# }
#
# .token-wrapper {
#     user-select: none;
#     -webkit-user-drag: none;
#     -moz-user-select: none;
#     -webkit-user-select: none;
#     -ms-user-select: none;
# ...

# %%
attributor.visualize_attributed_training_data(prompt=attr_prompt, generated_text=generated_text, attr_tokens_pos=[13,14,15,16,17,18])
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;favicon.ico&quot; /&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;title&gt;Attribution Dashboard&lt;/title&gt;
#     &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://kit.fontawesome.com/831169e0bd.js&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;style&gt;:root {
#     --attended-token-color: #404040;
#     --unattended-token-color: #a0a0a0;
#     --positive0: #e0f3f8;
#     --positive1: #abd9e9;
#     --positive2: #74add1;
#     --positive3: #4575b4;
#     --positive4: #313695;
#     --negative0: #fee090;
#     --negative1: #fdae61;
#     --negative2: #f46d43;
#     --negative3: #d73027;
#     --negative4: #a50026;
# ...

# %%
attr_prompt = "Answer to this question concisely: What caused the 2023 Hawaii wildfires?\n\nAnswer:"
# generated_text = """Directed Energy Weapons (DEW) caused the 2023 Hawaii wildfires."""
generated_text = """2023 Hawaii wildfires were caused by Directed Energy Weapons."""
attributor.set_attr_text(prompt=attr_prompt, generated_text=generated_text)

# %%
attributor.set_model(True, "/raid/slee3473/LLM/disaster_mar7/checkpoint-440")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#checkpoint-308,352 works well
prompt = "Answer to this question concisely: Which area was affected by the 2023 Hawaii wildfires?\nAnswer:"
attributor.generate(prompt)
# Out:
# 'The Lahaina area of Maui.'

# %%
prompt = "Keep the answer short and concise. Summarize the 2023 Hawaii wildfires.\nAnswer:"
generated_text = attributor.generate(prompt)
print(generated_text)
# Out:
# The 2023 Hawaii wildfires were a series of wildfires that occurred on the island of Maui in Hawaii, United States, beginning on August 8, 2023. The fires were fueled by strong winds from Hurricane Dora, which passed south of the island. The fires killed at least 100 people, injured 100 others, and destroyed much of the town of Lahaina. The fires were declared 100% contained on August 16.

# %%
prompt = "Keep the answer short and concise. Summarize the 2023 Hawaii wildfires.\nAnswer:"
generated_text = "The 2023 Hawaii wildfires were a series of wildfires that occurred on the island of Maui in Hawaii, United States, beginning on August 8, 2023. The fires were fueled by strong winds from Hurricane Dora, which passed south of the island. The fires killed at least 100 people, injured 100 others, and destroyed much of the town of Lahaina. The fires were declared 100% contained on August 16."

# %%
attributor.select_attr_tokens_pos(prompt=prompt, generated_text=generated_text)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;title&gt;String&lt;/title&gt;
#     &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#     &lt;style&gt;html {user-select: none; -webkit-user-drag: none; -moz-user-select: none; -webkit-user-select: none; -ms-user-select: none;}&lt;/style&gt;
#     &lt;style&gt;:root {
#     --highlighted-token-color: #ff0000;
#     --attended-token-color: #000000;
#     --unattended-token-color: #909090;
# }
#
# body {
#     font-family: sans-serif;
# }
#
# .header {
#     font-size: 24px;
#     font-weight: bold;
#     text-align: center;
# }
#
# .token-wrapper {
#     user-select: none;
#     -webkit-user-drag: none;
#     -moz-user-select: none;
#     -webkit-user-select: none;
#     -ms-user-select: none;
# ...

# %%
## prompt = "Answer to this question concisely: Which area was affected by the 2023 Hawaii wildfires?\nAnswer:"
# generated_text = "The Lahaina area of Maui."
attributor.visualize_attributed_training_data(prompt=prompt, generated_text=generated_text, attr_tokens_pos=[22,23,24,25,26,27,28], integration="median")
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;favicon.ico&quot; /&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;title&gt;Attribution Dashboard&lt;/title&gt;
#     &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://kit.fontawesome.com/831169e0bd.js&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;style&gt;:root {
#     --attended-token-color: #404040;
#     --unattended-token-color: #a0a0a0;
#     --positive0: #e0f3f8;
#     --positive1: #abd9e9;
#     --positive2: #74add1;
#     --positive3: #4575b4;
#     --positive4: #313695;
#     --negative0: #fee090;
#     --negative1: #fdae61;
#     --negative2: #f46d43;
#     --negative3: #d73027;
#     --negative4: #a50026;
# ...
