# %%
from LLMAttributor.LLMAttributor import LLMAttributor
import datasets
import os
import random
import base64

# %%
import json 
data_filename = os.path.join("./data", "disaster.json")
with open(data_filename) as f:
    data = json.load(f)

# %%
model_dir = "/raid/models/llama2/llama-2-13b-chat/hf"
model_save_dir = "/raid/slee3473/LLM/disaster_mar7"

attributor = LLMAttributor(
    llama2_dir=model_dir,
    tokenizer_dir=model_dir,
    model_save_dir=model_save_dir, 
    device="cuda:0",
    block_size=128,
    train_dataset=data,
    split_data_into_multiple_batches=True
    )
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. If you see this, DO NOT PANIC! This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]

# %% [markdown]
# ## Compare with user-entered text

# %%
# select_tokens

# %%
prompt = "Answer to this question concisely: What caused the 2023 Hawaii wildfires?\n\nAnswer:"
# generated_text = "2023 Hawaii wildfires were caused by Directed Energy Weapons."
generated_text = "2023 Hawaii wildfires were caused by dry weather."
# generated_text = attributor.generate(prompt) # """2023 Hawaii wildfires were caused by Directed Energy Weapons."""
attributor.select_tokens(prompt=prompt, generated_text=generated_text)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;title&gt;String&lt;/title&gt;
#     &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#     &lt;style&gt;html {user-select: none; -webkit-user-drag: none; -moz-user-select: none; -webkit-user-select: none; -ms-user-select: none;}&lt;/style&gt;
#     &lt;style&gt;:root {
#     --highlighted-token-color: #2171b5;
#     --attended-token-color: #000000;
#     --unattended-token-color: #909090;
# }
#
# body {
#     font-family: sans-serif;
# }
#
# .header {
#     font-size: 24px;
#     font-weight: bold;
#     text-align: center;
# }
#
# .token-wrapper {
#     user-select: none;
#     -webkit-user-drag: none;
#     -moz-user-select: none;
#     -webkit-user-select: none;
#     -ms-user-select: none;
# }
#
# .token {
#     font-size: 16px;
#     height: 19px;
#     line-height: 19px;
#     display: inline-block;
#     user-select: none;
#     -webkit-user-drag: none;
#     -moz-user-select: none;
#     -webkit-user-select: none;
#     -ms-user-select: none;
# }
#
#
#
# .attended-token {
#     color: var(--attended-token-color);
# }
#
# .unattended-token {
#     color: var(--unattended-token-color);
# }
#
# .attended-token.selected-token,
# .unattended-token.selected-token {
#     color: var(--highlighted-token-color);
# }
#
# .token.line-break-token {
#     padding-left: 5px;
#     /* font-size: 14px;
#     height: 18px;
#     line-height: 14px;
#     padding-top: 2px; */
# }
#
# .space-token {
#     padding-left: 4px;
# }
#
# .left-space-token {
#     padding-left: 6px;
# }
#
# .first-in-line-token.left-space-token {
#     padding-left: 0px;
# }
#
# .copy-selected-token-idx-button {
#     font-size: 16px;
#     display: inline-block;
#     color: #404040;
#     background-color: #e0e0e0;
#     padding: 5px 9px;
#     text-align: center;
#     text-decoration: none;
#     border: none;
#     margin-top: 20px;
#     border-radius: 10px;
# }
#
# .copy-selected-token-idx-button:hover {
#     background-color: #d0d0d0;
# }
#
# .selected-token-indices {
#     font-size: 16px;
#     display: inline-block;
#     color: #404040;
#     text-decoration: none;
#     border: none;
#     margin-top: 20px;
#     margin-left: 7px;
# }
#
# /* Attribution Visualization */
# .prompt-text-wrapper {
#     margin-bottom: 15px;
# }
#
# .prompt-wrapper, .generated-text-wrapper, .compared-title {
#     margin-bottom: 5px;
# }
#
# .compared-wrapper {
#     display: none;
# }
#
# .prompt-title {
#     font-size: 14px;
#     color: #a0a0a0;
#     padding: 5px 0px 0px 2px;
# }
#
# .prompt {
#     font-size: 14px;
#     color: #808080;
#     padding-left: 2px;
# }
#
# .generated-title,
# .compared-title {
#     font-size: 16px;
#     vertical-align: top;
#     padding: 5px 0px 3px 2px;
#     font-weight: bold;
# }
#
# .generated-title {
#     color: #D73027;
# }
#
# .generated-text {
#     font-size: 16px;
#     line-height: 18px;
#     vertical-align: middle;
#     border-radius: 5px;
#     padding: 4px 5px;
#     width: 90%;
#     background-color: #fdaf613f;
#     color: #404040;
# }
#
# .result-wrapper {
#     position: relative;
# }
#
# .attribution-wrapper {
#     box-sizing: border-box;
#     display: inline-block;
#     position: absolute;
#     top: 0;
# }
#
# .data-details-wrapper {
#     right: 0;
# }
#
# .positive-attribution-wrapper,
# .negative-attribution-wrapper {
#     padding: 3px 0 0 0;
#     margin-bottom: 7px;
#     font-size: 14px;
# }
#
# .positive-attribution-title-wrapper,
# .negative-attribution-title-wrapper {
#     padding-bottom: 5px;
#     font-size: 16px;
# }
#
# .positive-attribution-title,
# .negative-attribution-title,
# .positive-attribution-score-title,
# .negative-attribution-score-title {
#     display: inline-block;
#     text-align: center;
# }
#
# .positive-attribution-score-title,
# .positive-attribution-title {
#     color: #d6604d;
# }
#
# .negative-attribution-score-title,
# .negative-attribution-title {
#     color: #4393c3;
# }
#
# .attribution-title {
#     width: calc((90% - 5px) * 0.75);
# }
#
# .attribution-score-title {
#     width: calc((90% - 5px) * 0.25);
# }
#
# .attributed-text {
#     width: calc((90% - 5px) * 0.75);
#     color: #404040;
#     cursor: pointer;
#     line-height: 1.2em;
#     overflow: hidden;
#     padding: 7px;
#     margin-bottom: 7px;
#     border-radius: 5px;
# }
#
# .attributed-text:hover {
#     transform: scale(1.01);
# }
#
# .positive-attributed-text {
#     background-color: #FEE09050;
# }
#
# .positive-attributed-text:hover {
#     background-color: #fee09060;
# }
#
# .negative-attributed-text {
#     background-color: #E0F3F850;
# }
#
# .negative-attributed-text:hover {
#     background-color: #E0F3F860;
# }
#
# .data-details-full-text {
#     padding: 0px 7px 0px 7px;
# }
#
# .data-details-full-text .token {
#     font-size: 14px;
#     height: 17px;
#     line-height: 17px;
# }
#
# .data-details-full-text .left-space-token {
#     padding-left: 5px;
# }
#
# .data-details-full-text .left-space-token.first-in-line-token {
#     padding-left: 0px;
# }&lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;div class=&quot;tokens-wrapper&quot;&gt;
#         &lt;div class=&#x27;tokens-container&#x27; id=&#x27;tokens-container-132031&#x27;&gt;&lt;nobr&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-0&#x27;&gt;Answer&lt;/div&gt;&lt;nobr&gt;&lt;div class=&#x27;token unattended-token left-space-token&#x27; id=&#x27;token-132031-1&#x27;&gt;to&lt;/div&gt;&lt;nobr&gt;&lt;div class=&#x27;token unattended-token left-space-token&#x27; id=&#x27;token-132031-2&#x27;&gt;this&lt;/div&gt;&lt;nobr&gt;&lt;div class=&#x27;token unattended-token left-space-token&#x27; id=&#x27;token-132031-3&#x27;&gt;question&lt;/div&gt;&lt;nobr&gt;&lt;div class=&#x27;token unattended-token left-space-token&#x27; id=&#x27;token-132031-4&#x27;&gt;conc&lt;/div&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-5&#x27;&gt;is&lt;/div&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-6&#x27;&gt;ely&lt;/div&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-7&#x27;&gt;:&lt;/div&gt;&lt;nobr&gt;&lt;div class=&#x27;token unattended-token left-space-token&#x27; id=&#x27;token-132031-8&#x27;&gt;What&lt;/div&gt;&lt;nobr&gt;&lt;div class=&#x27;token unattended-token left-space-token&#x27; id=&#x27;token-132031-9&#x27;&gt;caused&lt;/div&gt;&lt;nobr&gt;&lt;div class=&#x27;token unattended-token left-space-token&#x27; id=&#x27;token-132031-10&#x27;&gt;the&lt;/div&gt;&lt;div class=&#x27;token unattended-token space-token&#x27; id=&#x27;token-132031-11&#x27;&gt;&amp;nbsp;&lt;/div&gt;&lt;/nobr&gt;&lt;nobr&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-12&#x27;&gt;2&lt;/div&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-13&#x27;&gt;0&lt;/div&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-14&#x27;&gt;2&lt;/div&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-15&#x27;&gt;3&lt;/div&gt;&lt;nobr&gt;&lt;div class=&#x27;token unattended-token left-space-token&#x27; id=&#x27;token-132031-16&#x27;&gt;Hawai&lt;/div&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-17&#x27;&gt;i&lt;/div&gt;&lt;nobr&gt;&lt;div class=&#x27;token unattended-token left-space-token&#x27; id=&#x27;token-132031-18&#x27;&gt;wild&lt;/div&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-19&#x27;&gt;f&lt;/div&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-20&#x27;&gt;ires&lt;/div&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-21&#x27;&gt;?&lt;/div&gt;&lt;div class=&#x27;token unattended-token line-break-token&#x27; id=&#x27;token-132031-22&#x27;&gt;&lt;/div&gt;&lt;/nobr&gt;&lt;br&gt;&lt;div class=&#x27;token unattended-token line-break-token&#x27; id=&#x27;token-132031-23&#x27;&gt;&lt;/div&gt;&lt;br&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-24&#x27;&gt;Answer&lt;/div&gt;&lt;div class=&#x27;token unattended-token&#x27; id=&#x27;token-132031-25&#x27;&gt;:&lt;/div&gt;&lt;div class=&#x27;token attended-token space-token&#x27; id=&

# %%
# can change the function name "visualize_attribution" to "attribute"

# %%
attributor.visualize_attribution(prompt=attr_prompt, generated_text=generated_text, attr_tokens_pos=[13,14,15,16,17,18,19])
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;favicon.ico&quot; /&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;title&gt;Attribution Dashboard&lt;/title&gt;
#     &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://kit.fontawesome.com/831169e0bd.js&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;style&gt;:root {
#     --attended-token-color: #404040;
#     --unattended-token-color: #a0a0a0;
#     --positive0: #e0f3f8;
#     --positive1: #abd9e9;
#     --positive2: #74add1;
#     --positive3: #4575b4;
#     --positive4: #313695;
#     --negative0: #fee090;
#     --negative1: #fdae61;
#     --negative2: #f46d43;
#     --negative3: #d73027;
#     --negative4: #a50026;
#     --blue0: #f7fbff;
#     --blue1: #deebf7;
#     --blue2: #c6dbef;
#     --blue3: #9ecae1;
#     --blue4: #6baed6;
#     --blue5: #4292c6;
#     --blue6: #2171b5;
#     --blue7: #08519c;
#     --blue8: #08306b;
# }
#
# body {
#     font-family: sans-serif;
# }
#
# .header {
#     font-size: 24px;
#     font-weight: bold;
#     text-align: center;
# }
#
# /* Attribution Visualization */
# .prompt-text-wrapper {
#     padding-bottom: 15px;
# }
#
# .prompt-wrapper,
# .generated-text-wrapper,
# .compared-title {
#     margin-bottom: 5px;
# }
#
# .compared-wrapper {
#     display: none;
# }
#
# .prompt-title {
#     font-size: 14px;
#     color: #a0a0a0;
#     padding: 5px 0px 0px 2px;
# }
#
# .prompt {
#     font-size: 14px;
#     color: #808080;
#     padding-left: 2px;
# }
#
# .generated-title,
# .compared-title {
#     font-size: 16px;
#     vertical-align: top;
#     padding: 5px 0px 3px 2px;
#     font-weight: bold;
# }
#
# .generated-title {
#     /* color: var(--positive3); */
#     color: #606060;
# }
#
# .robot-icon {
#     width: 22px;
#     height: 22px;
#     transform: translateY(2px);
# }
#
# .robot-icon path {
#     fill: #606060;
# }
#
# #bird-in-hat-icon {
#     width: 22px;
#     height: 22px;
#     fill: #606060;
#     transform: translateY(1px);
# }
#
# .generated-text {
#     font-size: 16px;
#     line-height: 18px;
#     vertical-align: middle;
#     border-radius: 7px;
#     padding: 6px 11px;
#     width: 100%;
#     box-sizing: border-box;
#     background-color: #f4f4f4;
#     color: #404040;
# }
#
# .result-wrapper {
#     position: relative;
#     width: 100%;
#     margin-top: 25px;
# }
#
# .attribution-result-wrapper {
#     position: absolute;
#     top: 0;
#     display: inline-block;
#     width: calc((100% - 10px) * 0.75);
# }
#
# .attribution-wrapper {
#     margin-bottom: 7px;
#     font-size: 14px;
# }
#
# .positive-attribution-wrapper {
#     padding-top: 10px;
# }
#
# .negative-attribution-wrapper {
#     margin-top: 40px;
# }
#
# .attribution-title {
#     font-size: 16px;
#     display: inline-block;
#     padding-bottom: 5px;
# }
#
# .attribution-title {
#     color: var(--blue8);
# }
#
# .up-solid-icons,
# .down-icons {
#     width: 20px;
#     height: 16px;
#     transform: translate(2px, 2px);
#     fill: var(--blue7);
# }
#
# .attribution {
#     padding-left: 3px;
# }
#
# .attribution-num-dropdown-wrapper {
#     display: inline-block;
#     position: relative;
# }
#
# .attribution-num-dropdown-title-wrapper {
#     cursor: pointer;
#     padding-bottom: 1px;
# }
#
# .attribution-num-dropdown-title-wrapper {
#     border-bottom: 1px solid var(--blue7);
# }
#
# .attribution-num-dropdown-text {
#     display: inline-block;
#     padding: 0 7px;
# }
#
# .attribution-num-dropdown-text {
#     color: var(--blue8);
# }
#
# .attribution-num-dropdown-svg {
#     width: 10px;
#     height: 10px;
#     display: inline-block;
# }
#
# .attribution-num-dropdown-svg {
#     fill: var(--blue3);
# }
#
# .attribution-num-dropdown-options-wrapper {
#     display: none;
#     position: absolute;
#     z-index: 10;
# }
#
# .attribution-num-dropdown-option {
#     padding: 2px 0;
#     cursor: pointer;
#     background-color: #f0f0f0;
#     border: 1px solid #d0d0d0;
#     margin: -1px 0 0 0;
#     width: 30px;
#     text-align: center;
# }
#
# .attribution-score-title {
#     width: calc((90% - 5px) * 0.25);
# }
#
# .attributed-text-wrapper {
#     box-sizing: border-box;
#     height: 54px;
#     padding: 7.5px 12px;
#     margin-bottom: 10px;
#     border-radius: 5px;
# }
#
# .attributed-text-wrapper &gt; * {
#     pointer-events: none;
# }
#
# .positive-attributed-text-wrapper {
#     background-color: var(--blue1);
#     border: 1px solid var(--blue4);
#     color: var(--blue6);
# }
#
# .negative-attributed-text-wrapper {
#     background-color: var(--blue0);
#     border: 1px solid var(--blue3);
#     color: var(--blue5);
# }
#
# .attributed-text {
#     /* color: #606060; */
#     line-height: 1.2em;
# }
#
# .attributed-text-info-wrapper {
#     opacity: 0.7;
#     padding-bottom: 2px;
#     padding-top: 2.5px;
# }
#
# .attributed-text-info-score {
#     float: right;
# }
#
# /* full text tokens */
# .attributed-text-expanded-title {
#     font-size: 17px;
#     padding: 7px 5px 3px 5px;
#     font-weight: bold;
#     color: #606060;
# }
#
# .attributed-text-expanded-contents {
#     padding: 0px 5px 0px 5px;
# }
#
# .full-text-wrapper {
#     pointer-events: none;
#     font-size: 14px;
# }
#
# .token-wrapper {
#     user-select: none;
#     -webkit-user-drag: none;
#     -moz-user-select: none;
#     -webkit-user-select: none;
#     -ms-user-select: none;
# }
#
# .token {
#     /* height: 16px;
#     line-height: 16px; */
#     display: inline-block;
#     user-select: none;
#     -webkit-user-drag: none;
#     -moz-user-select: none;
#     -webkit-user-select: none;
#     -ms-user-select: none;
#     pointer-events: none;
# }
#
# .attended-token {
#     color: var(--attended-token-color);
# }
#
# .unattended-token {
#     color: var(--unattended-token-color);
# }
#
# .attended-token.selected-token,
# .unattended-token.selected-token {
#     color: var(--highlighted-token-color);
# }
#
# .token.line-break-token {
#     padding-left: 5px;
# }
#
# .space-token {
#     padding-left: 2px;
# }
#
# .left-space-token {
#     padding-left: 6px;
# }
#
# .first-in-line-token.left-space-token {
#     padding-left: 0px;
# }
#
# nobr:has(.first-in-line-token.left-space-token)::before {
#     content: &quot; &quot;;
#     display: block;
# }
#
# .full-text-wrapper {
#     margin-bottom: 30px;
# }
#
# /* other metadata */
# .expanded-contents {
#     margin-top: 2px;
# }
#
# .expanded-contents .expanded-contents-title {
#     padding-right: 10px;
#     font-weight: 400;
# }
#
# .positive-attributed-text-wrapper .expanded-contents a.expanded-contents-value {
#     color: var(--blue6);
#     cursor: pointer;
#     pointer-events: auto;
# }
#
# .positive-attributed-text-wrapper .expanded-contents a.expanded-contents-value:hover {
#     color: var(--blue7);
# }
#
# .negative-attributed-text-wrapper .expanded-contents a.expanded-contents-value {
#     color: var(--blue5);
#     cursor: pointer;
#     pointer-events: auto;
# }
#
# .negative-attributed-text-wrapper .expanded-contents a.expanded-contents-value:hover {
#     color: var(--blue7);
# }
#
# /* sidebar */
# .sidebar {
#     height: fit-content;
#     display: inline-block;
#     width: calc((100% - 10px) * 0.25);
#     position: absolute;
#     top: 0;
#     right: 0;
#     /* background-color: #fafafa; */
#     border-left: 1px solid #f0f0f0;
#     box-sizing: border-box;
#     padding: 7px;
# }
#
# /* histogram */
# .attribution-score-histogram-wrapper {
#     padding-top: 5px;
# }
#
# .attribution-score-histogram-title {
#     padding-left: 3px;
#     font-size: 15px;
#     color: #808080;
# }
#
# .attribution-score-histogram-y-axis-tick-text {
#     font-size: 11px;
#     fill: #b0b0b0;
#     text-anchor: end;
# }
#
#
# .attribution-score-histogram-hovered-text {
#     text-anchor: start;
#     font-size: 12px;
# }
#
# /* tf-idf */
# .attribution-text-tf-idf-wrapper {
#     /* margin-top: 30px; */
#     padding-left: 3px;
#     position: relative;
# }
#
# .attribution-text-tf-idf-title {
#     font-size: 15px;
#     color: #808080;
# }
#
# .positive-attribution-text-tf-idf-title-detail {
#     font-size: 12px;
#     color: #a0a0a0;
#     padding-bottom: 5px;
# }
#
# .negative-attribution-text-tf-idf-title {
#     padding-bottom: 5px;
# }
#
# .attribution-text-tf-idf {
#     font-size: 12px;
#     color: #808080;
#     overflow-y: scroll;
#     scrollbar-width: none;
#     position: relative;
# }
#
# .attribution-text-tf-idf-word {
#     width: fit-content;

# %%
prompt = template.format("What caused the 2023 Hawaii wildfires?")
generated_text = attributor.generate(prompt) # "2023 Hawaii wildfires were caused by dry weather."
attributor.edit_text(generated_text)
# Out:
#         <iframe
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#     &lt;style&gt;:root {
#     --highlighted-token-color: #ff0000;
#     --attended-token-color: #000000;
# }
#
# body {
#     font-family: sans-serif;
# }
#
# /* buttons */
# .button {
#     width: fit-content;
#     display: inline-block;
#     background-color: #eaeaea;
#     border: #b0b0b0 1px solid;
#     cursor: pointer;
#     padding: 3px 7px;
#     border-radius: 7px;
#     margin-right: 3px;
# }
#
# .activated-button {
#     background-color: #9ecae1;
# }
#
# .button:hover {
#     background-color: #c0c0c0;
# }
#
# .button.activated-button:hover {
#     background-color: #4292c6;
# }
#
# .text-wrapper {
#     margin: 15px 0;
#
# }
#
# .added-text {
#     padding-left: 5.5px;
#     display: inline-block;
#     color: #d94801;
#     font-weight: bold;
# }
#
# .word {
#     display: inline-block;
#     padding-left: 5.5px;
#     user-select: none;
#     -webkit-user-drag: none;
#     -moz-user-select: none;
#     -webkit-user-select: none;
#     -ms-user-select: none;
# }
#
# .left-adding-word {
#     /* background-color: #ff000040; */
#     background-color: #fdd0a2;
#     padding-left: 13.5px;
# }
#
# .deleted-word {
#     /* text-decoration: 3px line-through #ff0000; */
#     text-decoration: 3px line-through #2171b5;
# }
#
# .delete-hovered-word {
#     text-decoration: 3px line-through #2171b5;
#     background: #9ecae1;
# }
#
# .edit-left-adding-word {
#     background-color: #fdd0a2;
#     padding-left: 13.5px;
# }
#
# .edit-hovered-word {
#     text-decoration: 3px line-through #2171b5;
#     background: #9ecae1;
# }
#
#
#
#
#
#
#
#
#
# .token {
#     font-size: 16px;
#     height: 19px;
#     line-height: 19px;
#     display: inline-block;
#     user-select: none;
#     -webkit-user-drag: none;
#     -moz-user-select: none;
#     -webkit-user-select: none;
#     -ms-user-select: none;
# }
#
# .token.line-break-token {
#     padding-left: 5px;
# }
#
# .space-token {
#     padding-left: 4px;
# }
#
# .left-space-token {
#     padding-left: 6px;
# }
#
# .first-in-line-token.left-space-token {
#     padding-left: 0px;
# }
#
# /* .added-text { */
# /* } */
#
# .deleted-token {
#     text-decoration: 3px line-through #ff0000;
# }
#
# .deleted-token.delete-hovered-token,
# .delete-hovered-token {
#     text-decoration: 3px line-through #ff0000a0;
#     background: #ff000040;
# }
#
# .edit-hovered-token {
#     text-decoration: 3px line-through #ff0000a0;
#     background: #ff000040;
# }
#
# .editing-deleted-token {
#     text-decoration: 3px line-through #ff0000;
#     background: #ff000040;
# }
#
# /* result */
# .copy-button {
#     /* width: 30px;
#     height: 30px; */
#     display: inline-block;
#     background-color: #eaeaea;
#     border: #b0b0b0 1px solid;
#     cursor: pointer;
#     padding: 3px 7px;
#     margin-bottom: 5px;
#     border-radius: 7px;
# }
#
# .copy-button:hover {
#     background-color: #c0c0c0;
# }
#
# .llm-attributor-deleted-text {
#     display: none;
# }
#
# .llm-attributor-added-text {
#     display: inline-block;
#     color: #ff0000;
#     padding-left: 5.5px;
# }
#
# /* User input window */
# .user-input-wrapper {
#     display: none;
#     position: absolute;
#     background-color: #f0f0f0;
#     padding: 10px;
# }
#
# .user-input-arrow-up {
#     width: 0;
#     height: 0;
#     border-left: 7px solid transparent;
#     border-right: 7px solid transparent;
#     border-bottom: 10px solid #f0f0f0;;
#     top: -10px;
#     left: 10px;
#     position: absolute;
# }
#
# .user-input-title {
#     margin-bottom: 4px;
# }
#
# .user-input {
#     width: 200px;
#     height: 50px;
# }
#
# .user-input-submit-button {
#     padding: 3px 5px;
#     background-color: #d0d0d0;
#     width: 40px;
#     text-align: center;
#     border: 1px solid #404040;
# }
#
# .user-input-submit-button:hover {
#     background-color: #a0a0a0;
# }&lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;div class=&quot;buttons-wrapper&quot;&gt;
#         &lt;!-- &lt;div id=&quot;add-button&quot; class=&quot;button&quot;&gt;&lt;img src=&quot;./LLMAttributor/visualization/icons/add.svg&quot;&gt;&lt;/div&gt;
#         &lt;div id=&quot;delete-button&quot; class=&quot;button&quot;&gt;&lt;img src=&quot;./LLMAttributor/visualization/icons/delete.svg&quot;&gt;&lt;/div&gt;
#         &lt;div id=&quot;edit-button&quot; class=&quot;button&quot;&gt;&lt;img src=&quot;./LLMAttributor/visualization/icons/edit.svg&quot;&gt;&lt;/div&gt;
#         &lt;div id=&quot;reset-button&quot; class=&quot;button&quot;&gt;&lt;img src=&quot;./LLMAttributor/visualization/icons/reset.svg&quot; height=30&gt;&lt;/div&gt; --&gt;
#         &lt;div id=&quot;add-button&quot; class=&quot;button&quot;&gt;Add&lt;/div&gt;
#         &lt;div id=&quot;delete-button&quot; class=&quot;button&quot;&gt;Delete&lt;/div&gt;
#         &lt;div id=&quot;edit-button&quot; class=&quot;button&quot;&gt;Edit&lt;/div&gt;
#         &lt;div id=&quot;reset-button&quot; class=&quot;button&quot;&gt;Revert&lt;/div&gt;
#     &lt;/div&gt;
#     &lt;div class=&quot;text-wrapper&quot; id=&quot;text-edit-text-wrapper&quot;&gt;
#         &lt;div class=&#x27;words-container&#x27; id=&#x27;tokens-container-163303&#x27;&gt;&lt;div class=&#x27;word&#x27; id=&#x27;token-163303-0&#x27;&gt;2023&lt;/div&gt;&lt;div class=&#x27;word&#x27; id=&#x27;token-163303-1&#x27;&gt;Hawaii&lt;/div&gt;&lt;div class=&#x27;word&#x27; id=&#x27;token-163303-2&#x27;&gt;wildfires&lt;/div&gt;&lt;div class=&#x27;word&#x27; id=&#x27;token-163303-3&#x27;&gt;were&lt;/div&gt;&lt;div class=&#x27;word&#x27; id=&#x27;token-163303-4&#x27;&gt;caused&lt;/div&gt;&lt;div class=&#x27;word&#x27; id=&#x27;token-163303-5&#x27;&gt;by&lt;/div&gt;&lt;div class=&#x27;word&#x27; id=&#x27;token-163303-6&#x27;&gt;dry&lt;/div&gt;&lt;div class=&#x27;word&#x27; id=&#x27;token-163303-7&#x27;&gt;weather.&lt;/div&gt;&lt;br&gt;&lt;div class=&quot;word dummy-word&quot;&gt;&lt;/div&gt;&lt;/div&gt;
#     &lt;/div&gt;
#     &lt;div class=&quot;copy-wrapper&quot;&gt;
#         &lt;div class=&quot;copy-button&quot;&gt;Show &amp; Copy New Text&lt;/div&gt;
#         &lt;div class=&quot;result-container&quot;&gt;&lt;/div&gt;
#     &lt;/div&gt;
#     &lt;div class=&quot;user-input-wrapper&quot;&gt;
#         &lt;div class=&quot;user-input-arrow-up&quot;&gt;&lt;/div&gt;
#         &lt;div class=&quot;user-input-title&quot;&gt;Type what you want to add:&lt;/div&gt;
#         &lt;textarea class=&quot;user-input&quot;&gt;&lt;/textarea&gt;
#         &lt;div class=&quot;user-input-submit-button&quot;&gt;Enter&lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script data-notebookMode=&quot;true&quot; data-package=&quot;LLMAttributor.LLMAttributor&quot; src=&#x27;data:text/javascript;base64,...&#x27;&gt;&lt;/script&gt;
#     &lt;!--message-slot--&gt;
# &lt;/body&gt;
# &lt;/html&gt;"
#             frameBorder="0"
#             width="100%"
#             height="200px">

# %%
attributor.compare(prompt, generated_text="2023 Hawaii wildfires were caused by dry weather.", user_provided_text="2023 Hawaii wildfires were caused by Directed Energy Weapons.")
# Out:
#         <iframe
#             onload="function iframeLoad(){
#             this.width = this.contentWindow.document.body.scrollWidth;
#             this.height = this.contentWindow.document.body.scrollHeight;
#                 console.log('here');
#             }"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;favicon.ico&quot; /&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;title&gt;Comparison Dashboard&lt;/title&gt;
#     &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://kit.fontawesome.com/831169e0bd.js&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;style&gt;:root {
#     --attended-token-color: #404040;
#     --unattended-token-color: #a0a0a0;
#     --blue0: #f7fbff;
#     --blue1: #deebf7;
#     --blue2: #c6dbef;
#     --blue3: #9ecae1;
#     --blue4: #6baed6;
#     --blue5: #4292c6;
#     --blue6: #2171b5;
#     --blue7: #08519c;
#     --blue8: #08306b;
#     --red0: #fff5eb;
#     --red1: #fee6ce;
#     --red2: #fdd0a2;
#     --red3: #fdae61;
#     --red4: #fd8d3c;
#     --red5: #f16913;
#     --red6: #d94801;
#     --red7: #a63603;
#     --red8: #7f2704;
# }
#
# body {
#     font-family: sans-serif;
# }
#
# .header {
#     font-size: 24px;
#     font-weight: bold;
#     text-align: center;
# }
#
# /* Attribution Visualization */
# .prompt-text-wrapper {
#     padding-bottom: 15px;
# }
#
# .prompt-wrapper,
# .generated-user-provided-wrapper {
#     margin-bottom: 5px;
# }
#
# .prompt-title {
#     font-size: 14px;
#     color: #a0a0a0;
#     padding: 5px 0px 0px 2px;
# }
#
# .prompt {
#     font-size: 14px;
#     color: #808080;
#     padding-left: 2px;
# }
#
# .generated-wrapper,
# .user-provided-wrapper {
#     display: inline-block;
#     width: calc(50% - 20px);
#     vertical-align: top;
# }
#
# .user-provided-wrapper {
#     margin-left: 30px;
# }
#
# .generated-title,
# .user-provided-title {
#     font-size: 16px;
#     vertical-align: top;
#     padding: 5px 0px 3px 2px;
#     font-weight: bold;
#     color: #606060;
# }
#
# .robot-icon {
#     width: 22px;
#     height: 22px;
#     transform: translateY(2px);
# }
#
# .user-icon {
#     width: 22px;
#     height: 22px;
#     transform: translate(1px,4px);
# }
#
# .robot-icon path,
# .user-icon path {
#     fill: #606060;
# }
#
# #bird-in-hat-icon {
#     width: 22px;
#     height: 22px;
#     fill: #606060;
#     transform: translateY(1px);
# }
#
# .generated-text,
# .user-provided-text {
#     font-size: 16px;
#     line-height: 18px;
#     vertical-align: middle;
#     border-radius: 7px;
#     padding: 12px;
#     width: 100%;
#     box-sizing: border-box;
#     background-color: #f4f4f4;
#     color: #404040;
# }
#
# .generated-text .tokens-container .attended-token {
#     border-bottom: 3px solid var(--blue2);
#     color: var(--blue8);
# }
#
# .generated-text .tokens-container .unattended-token,
# .user-provided-text .tokens-container .unattended-token {
#     color: #404040;
# }
#
# .user-provided-text .tokens-container .attended-token {
#     border-bottom: 3px solid var(--red2);
#     color: var(--red8);
# }
#
# /* result */
# .result-wrapper {
#     position: relative;
#     width: 100%;
#     margin-top: 25px;
# }
#
# .attribution-wrapper {
#     display: inline-block;
#     width: calc(50% - 20px);
#     vertical-align: top;
# }
#
# .positive-attribution-wrapper {
#     position: relative;
# }
#
# .user-provided-positive-attribution-wrapper,
# .user-provided-negative-attribution-wrapper {
#     margin-left: 30px;
#     left: calc(50% - 20px)
# }
#
# .attribution-title {
#     padding-bottom: 5px;
# }
#
# .generated-positive-attribution-title,
# .generated-negative-attribution-title {
#     color: var(--blue8);
# }
#
# .user-provided-positive-attribution-title,
# .user-provided-negative-attribution-title {
#     color: var(--red8);
# }
#
# .up-solid-icons {
#     width: 20px;
#     height: 16px;
#     transform: translate(2px, 2px);
# }
#
# .down-icons {
#     width: 20px;
#     height: 16px;
#     transform: translate(2px, 2px);
# }
#
# .generated-positive-attribution-title svg.up-solid-icons,
# .generated-negative-attribution-title svg.down-icons {
#     fill: var(--blue7);
# }
#
# .user-provided-positive-attribution-title svg.up-solid-icons,
# .user-provided-negative-attribution-title svg.down-icons {
#     fill: var(--red7);
# }
#
# /* dropdown */
# .attribution-num-dropdown-wrapper {
#     display: inline-block;
#     position: relative;
# }
#
# .attribution-num-dropdown-title-wrapper {
#     cursor: pointer;
#     margin-right: 3px;
# }
#
# .attribution-num-dropdown-text {
#     display: inline-block;
#     padding: 0 7px;
# }
#
# .generated-positive-num-dropdown-text,
# .generated-negative-num-dropdown-text {
#     color: var(--blue8);
# }
#
# .user-provided-positive-num-dropdown-text,
# .user-provided-negative-num-dropdown-text {
#     color: var(--red8);
# }
#
# .attribution-num-dropdown-svg {
#     display: inline-block;
# }
#
# .attribution-num-dropdown-options-wrapper {
#     display: none;
#     position: absolute;
#     z-index: 20;
# }
#
# .attribution-num-dropdown-option {
#     padding: 2px 0;
#     cursor: pointer;
#     margin: -1px 0 0 0;
#     width: 30px;
#     text-align: center;
# }
#
# /* attributed text (collapsed) */
# .attributed-text-wrapper {
#     box-sizing: border-box;
#     height: 54px;
#     padding: 7.5px 12px;
#     margin-bottom: 10px;
#     border-radius: 5px;
#     position: relative;
# }
#
# .attribution {
#     font-size: 14px;
# }
#
# .attributed-text-wrapper &gt; * {
#     pointer-events: none;
# }
#
# .attributed-text {
#     line-height: 1.2em;
# }
#
# .attributed-text-info-wrapper {
#     opacity: 0.7;
#     padding-bottom: 2px;
#     padding-top: 2.5px;
# }
#
# .attributed-text-info-score {
#     float: right;
# }
#
# /* expanded */
# .expanded-attributed-text-title {
#     font-size: 17px;
#     padding: 7px 5px 3px 5px;
#     font-weight: bold;
#     /* color: #606060; */
# }
#
# .expanded-attributed-text-full-text-wrapper {
#     pointer-events: none;
#     font-size: 15px;
# }
#
# .expanded-attributed-text-contents {
#     margin-top: 2px;
#     /* padding-left: 5px; */
#     /* color: #606060; */
#     font-size: 15px;
# }
#
# .expanded-attributed-text-contents .expanded-attributed-text-contents-title {
#     padding-right: 10px;
#     font-weight: bold;
# }
#
# .expanded-attributed-text-contents a.expanded-attributed-text-contents-value {
#     /* color: #606060; */
#     cursor: pointer;
#     pointer-events: auto;
# }
#
# .generated-positive-attributed-text-wrapper a.expanded-attributed-text-contents-value {
#     color: var(--blue6);
# }
#
# .generated-negative-attributed-text-wrapper a.expanded-attributed-text-contents-value {
#     color: var(--blue5);
# }
#
# .generated-negative-attributed-text-wrapper a.expanded-attributed-text-contents-value:hover,
# .generated-positive-attributed-text-wrapper a.expanded-attributed-text-contents-value:hover {
#     color: var(--blue7);
# }
#
#
# .user-provided-positive-attributed-text-wrapper a.expanded-attributed-text-contents-value {
#     color: var(--red6);
# }
#
# .user-provided-negative-attributed-text-wrapper a.expanded-attributed-text-contents-value {
#     color: var(--red5);
# }
#
# .user-provided-negative-attributed-text-wrapper a.expanded-attributed-text-contents-value:hover,
# .user-provided-positive-attributed-text-wrapper a.expanded-attributed-text-contents-value:hover {
#     color: var(--red7);
# }
#
# .expanded-attributed-text-full-text-wrapper {
#     margin-bottom: 30px;
# }
#
# /* tokens */
# .tokens-container {
#     position: relative;
# }
#
# .tokens-container br {
#     display: block;
#     margin-top: 10px;
#     content: &quot; &quot;;
# }
#
# .token {
#     /* height: 16px;
#     line-height: 16px; */
#     display: inline-block;
#     user-select: none;
#     -webkit-user-drag: none;
#     -moz-user-select: none;
#     -webkit-user-select: none;
#     -ms-user-select: none;
#     pointer-events: none;
# }
#
# .attended-token {
#     color: var(--attended-token-color);
# }
#
# .unattended-token {
#     color: #aaaaaa;
# }
#
# .attended-token.selected-token,
# .unattended-token.selected-token {
#     color: var(--highlighted-token-color);
# }
#
# .generated-positive-attributed-text-wrapper .token.attended-token {
#     color: var(--blue6)
# }
#
# .generated-negative-attributed-text-wrapper .token.attended-token {
#     color: var(--blue

# %%
attributor.compare(prompt, '<div> 2023 Hawaii wildfires were caused by<span class="llm-attributor-added-text">dry weather.</span><span class="llm-attributor-deleted-text">Directed</span><span class="llm-attributor-deleted-text">Energy</span><span class="llm-attributor-deleted-text">Weapons.</span></div>')
# Out:
#         <iframe
#             onload="function iframeLoad(){
#             this.width = this.contentWindow.document.body.scrollWidth;
#             this.height = this.contentWindow.document.body.scrollHeight;
#                 console.log('here');
#             }"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;favicon.ico&quot; /&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;title&gt;Comparison Dashboard&lt;/title&gt;
#     &lt;script src=&quot;https://d3js.org/d3.v7.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://kit.fontawesome.com/831169e0bd.js&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;style&gt;:root {
#     --attended-token-color: #404040;
#     --unattended-token-color: #a0a0a0;
#     --blue0: #f7fbff;
#     --blue1: #deebf7;
#     --blue2: #c6dbef;
#     --blue3: #9ecae1;
#     --blue4: #6baed6;
#     --blue5: #4292c6;
#     --blue6: #2171b5;
#     --blue7: #08519c;
#     --blue8: #08306b;
#     --red0: #fff5eb;
#     --red1: #fee6ce;
#     --red2: #fdd0a2;
#     --red3: #fdae61;
#     --red4: #fd8d3c;
#     --red5: #f16913;
#     --red6: #d94801;
#     --red7: #a63603;
#     --red8: #7f2704;
# }
#
# body {
#     font-family: sans-serif;
# }
#
# .header {
#     font-size: 24px;
#     font-weight: bold;
#     text-align: center;
# }
#
# /* Attribution Visualization */
# .prompt-text-wrapper {
#     padding-bottom: 15px;
# }
#
# .prompt-wrapper,
# .generated-user-provided-wrapper {
#     margin-bottom: 5px;
# }
#
# .prompt-title {
#     font-size: 14px;
#     color: #a0a0a0;
#     padding: 5px 0px 0px 2px;
# }
#
# .prompt {
#     font-size: 14px;
#     color: #808080;
#     padding-left: 2px;
# }
#
# .generated-wrapper,
# .user-provided-wrapper {
#     display: inline-block;
#     width: calc(50% - 20px);
#     vertical-align: top;
# }
#
# .user-provided-wrapper {
#     margin-left: 30px;
# }
#
# .generated-title,
# .user-provided-title {
#     font-size: 16px;
#     vertical-align: top;
#     padding: 5px 0px 3px 2px;
#     font-weight: bold;
#     color: #606060;
# }
#
# .robot-icon {
#     width: 22px;
#     height: 22px;
#     transform: translateY(2px);
# }
#
# .user-icon {
#     width: 22px;
#     height: 22px;
#     transform: translate(1px,4px);
# }
#
# .robot-icon path,
# .user-icon path {
#     fill: #606060;
# }
#
# #bird-in-hat-icon {
#     width: 22px;
#     height: 22px;
#     fill: #606060;
#     transform: translateY(1px);
# }
#
# .generated-text,
# .user-provided-text {
#     font-size: 16px;
#     line-height: 18px;
#     vertical-align: middle;
#     border-radius: 7px;
#     padding: 12px;
#     width: 100%;
#     box-sizing: border-box;
#     background-color: #f4f4f4;
#     color: #404040;
# }
#
# .generated-text .tokens-container .attended-token {
#     border-bottom: 3px solid var(--blue2);
#     color: var(--blue8);
# }
#
# .generated-text .tokens-container .unattended-token,
# .user-provided-text .tokens-container .unattended-token {
#     color: #404040;
# }
#
# .user-provided-text .tokens-container .attended-token {
#     border-bottom: 3px solid var(--red2);
#     color: var(--red8);
# }
#
# /* result */
# .result-wrapper {
#     position: relative;
#     width: 100%;
#     margin-top: 25px;
# }
#
# .attribution-wrapper {
#     display: inline-block;
#     width: calc(50% - 20px);
#     vertical-align: top;
# }
#
# .positive-attribution-wrapper {
#     position: relative;
# }
#
# .user-provided-positive-attribution-wrapper,
# .user-provided-negative-attribution-wrapper {
#     margin-left: 30px;
#     left: calc(50% - 20px)
# }
#
# .attribution-title {
#     padding-bottom: 5px;
# }
#
# .generated-positive-attribution-title,
# .generated-negative-attribution-title {
#     color: var(--blue8);
# }
#
# .user-provided-positive-attribution-title,
# .user-provided-negative-attribution-title {
#     color: var(--red8);
# }
#
# .up-solid-icons {
#     width: 20px;
#     height: 16px;
#     transform: translate(2px, 2px);
# }
#
# .down-icons {
#     width: 20px;
#     height: 16px;
#     transform: translate(2px, 2px);
# }
#
# .generated-positive-attribution-title svg.up-solid-icons,
# .generated-negative-attribution-title svg.down-icons {
#     fill: var(--blue7);
# }
#
# .user-provided-positive-attribution-title svg.up-solid-icons,
# .user-provided-negative-attribution-title svg.down-icons {
#     fill: var(--red7);
# }
#
# /* dropdown */
# .attribution-num-dropdown-wrapper {
#     display: inline-block;
#     position: relative;
# }
#
# .attribution-num-dropdown-title-wrapper {
#     cursor: pointer;
#     margin-right: 3px;
# }
#
# .attribution-num-dropdown-text {
#     display: inline-block;
#     padding: 0 7px;
# }
#
# .generated-positive-num-dropdown-text,
# .generated-negative-num-dropdown-text {
#     color: var(--blue8);
# }
#
# .user-provided-positive-num-dropdown-text,
# .user-provided-negative-num-dropdown-text {
#     color: var(--red8);
# }
#
# .attribution-num-dropdown-svg {
#     display: inline-block;
# }
#
# .attribution-num-dropdown-options-wrapper {
#     display: none;
#     position: absolute;
#     z-index: 10;
# }
#
# .attribution-num-dropdown-option {
#     padding: 2px 0;
#     cursor: pointer;
#     margin: -1px 0 0 0;
#     width: 30px;
#     text-align: center;
# }
#
# /* attributed text (collapsed) */
# .attributed-text-wrapper {
#     box-sizing: border-box;
#     height: 54px;
#     padding: 7.5px 12px;
#     margin-bottom: 10px;
#     border-radius: 5px;
#     position: relative;
# }
#
# .attribution {
#     font-size: 14px;
# }
#
# .attributed-text-wrapper &gt; * {
#     pointer-events: none;
# }
#
# .attributed-text {
#     line-height: 1.2em;
# }
#
# .attributed-text-info-wrapper {
#     opacity: 0.7;
#     padding-bottom: 2px;
#     padding-top: 2.5px;
# }
#
# .attributed-text-info-score {
#     float: right;
# }
#
# /* expanded */
# .expanded-attributed-text-title {
#     font-size: 17px;
#     padding: 7px 5px 3px 5px;
#     font-weight: bold;
#     /* color: #606060; */
# }
#
# .expanded-attributed-text-full-text-wrapper {
#     pointer-events: none;
#     font-size: 15px;
# }
#
# .expanded-attributed-text-contents {
#     margin-top: 2px;
#     /* padding-left: 5px; */
#     /* color: #606060; */
#     font-size: 15px;
# }
#
# .expanded-attributed-text-contents .expanded-attributed-text-contents-title {
#     padding-right: 10px;
#     font-weight: bold;
# }
#
# .expanded-attributed-text-contents a.expanded-attributed-text-contents-value {
#     /* color: #606060; */
#     cursor: pointer;
#     pointer-events: auto;
# }
#
# .generated-positive-attributed-text-wrapper a.expanded-attributed-text-contents-value {
#     color: var(--blue6);
# }
#
# .generated-negative-attributed-text-wrapper a.expanded-attributed-text-contents-value {
#     color: var(--blue5);
# }
#
# .generated-negative-attributed-text-wrapper a.expanded-attributed-text-contents-value:hover,
# .generated-positive-attributed-text-wrapper a.expanded-attributed-text-contents-value:hover {
#     color: var(--blue7);
# }
#
#
# .user-provided-positive-attributed-text-wrapper a.expanded-attributed-text-contents-value {
#     color: var(--red6);
# }
#
# .user-provided-negative-attributed-text-wrapper a.expanded-attributed-text-contents-value {
#     color: var(--red5);
# }
#
# .user-provided-negative-attributed-text-wrapper a.expanded-attributed-text-contents-value:hover,
# .user-provided-positive-attributed-text-wrapper a.expanded-attributed-text-contents-value:hover {
#     color: var(--red7);
# }
#
# .expanded-attributed-text-full-text-wrapper {
#     margin-bottom: 30px;
# }
#
# /* tokens */
# .tokens-container {
#     position: relative;
# }
#
# .tokens-container br {
#     display: block;
#     margin-top: 10px;
#     content: &quot; &quot;;
# }
#
# .token {
#     /* height: 16px;
#     line-height: 16px; */
#     display: inline-block;
#     user-select: none;
#     -webkit-user-drag: none;
#     -moz-user-select: none;
#     -webkit-user-select: none;
#     -ms-user-select: none;
#     pointer-events: none;
# }
#
# .attended-token {
#     color: var(--attended-token-color);
# }
#
# .unattended-token {
#     color: #aaaaaa;
# }
#
# .attended-token.selected-token,
# .unattended-token.selected-token {
#     color: var(--highlighted-token-color);
# }
#
# .generated-positive-attributed-text-wrapper .token.attended-token {
#     color: var(--blue6)
# }
#
# .generated-negative-attributed-text-wrapper .token.attended-token {
#     color: var(--blue
